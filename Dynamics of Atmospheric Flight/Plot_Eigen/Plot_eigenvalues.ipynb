# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
#Base

Phug1_base = -0.042750 + 1.39519j
Phug2_base = -0.042750 - 1.39519j
Short1_base = -8.29522
Short2_base = -14.9848

Roll_base = -39.9953
Spiral_base = -0.10316

Dutch1_base = -1.74359 + 2.77022j
Dutch2_base = -1.74359 - 2.77022j

#6917 new

Phug1_new = -0.126437 + 1.72971j
Phug2_new = -0.126437 - 1.72971j
Short1_new = -7.1122889
Short2_new = -21.808023

Roll_new = -87.520399
Spiral_new = -1.38787

Dutch1_new = -1.376418 + 1.2205306j
Dutch2_new = -1.376418 - 1.2205306j

# %%
#plot it all

eigen = plt.figure(figsize=[8,5])
plt.axvline(x=0, color='black', linestyle='--', linewidth=0.8)
plt.axhline(y=0, color='black', linestyle='--', linewidth=0.8)

plt.scatter(Phug1_base.real,Phug1_base.imag,label='Phugiod Base',marker='v',color='orange')
plt.scatter(Phug2_base.real,Phug2_base.imag,marker='v',color='orange')
plt.scatter(Short1_base.real,Short1_base.imag,label='Short Base',color='orange',marker='s')
plt.scatter(Short2_base.real,Short2_base.imag,color='orange',marker='s')
plt.scatter(Spiral_base.real,Spiral_base.imag,label='Spiral Base',color='orange',marker='o')
plt.scatter(Roll_base.real,Roll_base.imag,label='Roll Base',color='orange',marker='x')
plt.scatter(Dutch1_base.real,Dutch1_base.imag,label='Dutch Base',color='orange',marker='^')
plt.scatter(Dutch2_base.real,Dutch2_base.imag,color='orange',marker='^')

plt.scatter(Phug1_new.real, Phug1_new.imag, label='Phugoid New', marker='v', color='blue')
plt.scatter(Phug2_new.real, Phug2_new.imag, marker='v', color='blue')
plt.scatter(Short1_new, 0, label='Short New', color='blue', marker='s')
plt.scatter(Short2_new, 0, color='blue', marker='s')
plt.scatter(Spiral_new, 0,label='Spiral New', color='blue', marker='o')
plt.scatter(Roll_new, 0,label='Roll New', color='blue', marker='x')
plt.scatter(Dutch1_new.real, Dutch1_new.imag,label='Dutch New', color='blue', marker='^')
plt.scatter(Dutch2_new.real, Dutch2_new.imag, color='blue', marker='^')

# Add labels and a legend
plt.xlabel('Real Part')
plt.ylabel('Imaginary Part')
plt.title('Glider Eigenvalues Compared')
plt.legend(loc='upper left', bbox_to_anchor=(1.05, 1))
plt.tight_layout()
plt.savefig('Eigenvalues_Compared.png',dpi=200)
